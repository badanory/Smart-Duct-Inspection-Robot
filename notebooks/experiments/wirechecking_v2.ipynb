# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/wire_break_models/modelv1.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model.train(
    data="/content/Wire_damage_byson-1/data.yaml",
    epochs=50,                             # 원하는 Epoch 수
    project="runs/train",
    name="wire_break_exp2",               # 새 결과 디렉토리 이름
    resume=False                           # 새로 시작하되 기존 모델에서 이어받음
)
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/drive/MyDrive/wire_break_dataset/data.yaml /content/
# Out:
# cp: cannot stat '/content/drive/MyDrive/wire_break_dataset/data.yaml': No such file or directory

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="1R0h7dpWnUesIXZTWQnf")
project = rf.workspace("wiredamagedetect").project("wire_damage_byson")
dataset = project.version(1).download("yolov8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-f94ea4c6a13b> in <cell line: 0>()
# ----> 1 from roboflow import Roboflow
#       2 rf = Roboflow(api_key="1R0h7dpWnUesIXZTWQnf")
#       3 project = rf.workspace("wiredamagedetect").project("wire_damage_byson")
#       4 dataset = project.version(1).download("yolov8")
#
# ModuleNotFoundError: No module named 'roboflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 121.9 MB/s eta 0:00:00

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="1R0h7dpWnUesIXZTWQnf")
project = rf.workspace("wiredamagedetect").project("wire_damage_byson")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Wire_damage_byson-1 in yolov8:: 100%|██████████| 560/560 [00:00<00:00, 8861.13it/s]

# %%
model.train(
    data="/content/Wire_damage_byson-1/data.yaml",
    epochs=50,
    name="wire_break_exp2"
)
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install scikit-learn

# %%
from IPython.display import Image
Image(filename='runs/train/wire_break_exp1/results.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-f0fa528b9ab3> in <cell line: 0>()
#       1 from IPython.display import Image
# ----> 2 Image(filename='runs/train/wire_break_exp1/results.png')
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
Image(filename='runs/train/wire_break_exp2/results.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-5fef3121f6eb> in <cell line: 0>()
# ----> 1 Image(filename='runs/train/wire_break_exp2/results.png')
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
# !ls runs/train/wire_break_exp2/
# Out:
# args.yaml  weights

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.128 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1137.8±661.9 MB/s, size: 38.9 KB)
# val: Scanning /content/Wire_damage_byson-1/valid/labels.cache... 23 images, 0 backgrounds, 0 corrupt: 100%|██████████| 23/23 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
#                    all         23         54      0.609      0.611      0.587      0.171
# Speed: 5.4ms preprocess, 9.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/wire_break_exp22
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7ed8d18e3750>
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('/content/runs/detect/train/results.png')

plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.title("YOLOv8 학습 과정 시각화 (Train vs Val)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c3b2d931f2cc> in <cell line: 0>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 img = Image.open('/content/runs/detect/train/results.png')
#       5
#       6 plt.figure(figsize=(12, 8))
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3503
#    3504     if filename:
# -> 3505         fp = builtins.open(filename, "rb")
#    3506         exclusive_fp = True
#    3507     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/train/results.png'

# %%
import os
for root, dirs, files in os.walk("/content/runs"):
    for file in files:
        if "results" in file:
            print(os.path.join(root, file))
# Out:
# /content/runs/detect/wire_break_exp2/results.csv
# /content/runs/detect/wire_break_exp2/results.png

# %%
from PIL import Image
import matplotlib.pyplot as plt

# 이미지 불러오기
img = Image.open('/content/runs/detect/wire_break_exp2/results.png')

# 이미지 시각화
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')  # 축 제거
plt.title("YOLOv8 학습 과정 시각화")
plt.show()
# Out:
# Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from font(s) DejaVu Sans.
# Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
# Glyph 44284 (\N{HANGUL SYLLABLE GWA}) missing from font(s) DejaVu Sans.
# Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
# Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
# Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
# Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# 이미지 불러오기
img = Image.open('/content/runs/detect/wire_break_exp2/results.png')

# 이미지 시각화
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')  # 축 제거
plt.title("YOLOv8 학습 과정 시각화")
plt.show()
